# %%
library(readr)
library(dplyr)
library(sqldf);

# %%
invisible({
person <- read_csv(unz("mimic_IV_omop_data_csv.zip", "mimic_IV_omop_data_csv/person.csv"))

condition_occurrence <- read_csv(unz("mimic_IV_omop_data_csv.zip", "mimic_IV_omop_data_csv/condition_occurrence.csv"))

procedure_occurrence <- read_csv(unz("mimic_IV_omop_data_csv.zip", "mimic_IV_omop_data_csv/procedure_occurrence.csv"))

measurement <- read_csv(unz("mimic_IV_omop_data_csv.zip", "mimic_IV_omop_data_csv/measurement.csv"))

visit_occurrence <- read_csv(unz("mimic_IV_omop_data_csv.zip", "mimic_IV_omop_data_csv/visit_occurrence.csv"))

drug_exposure <- read_csv(unz("mimic_IV_omop_data_csv.zip", "mimic_IV_omop_data_csv/drug_exposure.csv"))

observation <- read_csv(unz("mimic_IV_omop_data_csv.zip", "mimic_IV_omop_data_csv/observation.csv"))

concept <- read_csv(unz("mimic_IV_omop_data_csv.zip", "mimic_IV_omop_data_csv/2b_concept.csv"))

concept_relationship <- read_csv(unz("mimic_IV_omop_data_csv.zip", "mimic_IV_omop_data_csv/2b_concept_relationship.csv"))
    })
# Out:
# Rows: 100 Columns: 18
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): gender_source_value, race_source_value, ethnicity_source_value
# dbl (9): person_id, gender_concept_id, year_of_birth, race_concept_id, ethni...
# lgl (6): month_of_birth, day_of_birth, birth_datetime, location_id, provider...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 16441 Columns: 16
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): condition_source_value
# dbl  (6): condition_occurrence_id, person_id, condition_concept_id, conditio...
# lgl  (5): stop_reason, provider_id, visit_detail_id, condition_status_source...
# dttm (2): condition_start_datetime, condition_end_datetime
# date (2): condition_start_date, condition_end_date
#
# ...

# %%
head(person)
# Out:
#   person_id     gender_concept_id year_of_birth month_of_birth day_of_birth
# 1  3.589913e+18 8507              2095          NA             NA
# 2 -3.210374e+18 8507              2079          NA             NA
# 3 -7.755176e+17 8507              2149          NA             NA
# 4 -2.575767e+18 8507              2050          NA             NA
# 5 -8.970844e+18 8507              2114          NA             NA
# 6  4.668337e+18 8507              2073          NA             NA
#   birth_datetime race_concept_id ethnicity_concept_id location_id provider_id
# 1 NA                0            38003563             NA          NA
# 2 NA                0            38003563             NA          NA
# 3 NA             8516                   0             NA          NA
# 4 NA             8516                   0             NA          NA
# 5 NA             8527                   0             NA          NA
# 6 NA             8527                   0             NA          NA
# ...

# %%
person %>%
select(person_id, gender_concept_id, gender_source_value) %>%
head()
# Out:
#   person_id     gender_concept_id gender_source_value
# 1  3.589913e+18 8507              M
# 2 -3.210374e+18 8507              M
# 3 -7.755176e+17 8507              M
# 4 -2.575767e+18 8507              M
# 5 -8.970844e+18 8507              M
# 6  4.668337e+18 8507              M

# %%
condition_occurrence %>%
select(condition_occurrence_id, condition_concept_id, condition_source_value) %>%
head()
# Out:
#   condition_occurrence_id condition_concept_id condition_source_value
# 1  7.000818e+18             196523             78791
# 2 -3.514320e+18             436659             2809
# 3 -6.297447e+18             435515             2761
# 4  3.131133e+18             436096             33829
# 5  2.246710e+18             440383             311
# 6  3.281005e+18           37311319             27652

# %%
sqldf("select 
        condition_occurrence_id,
        condition_concept_id,
        condition_source_value,
        concept_name
       from condition_occurrence a LEFT JOIN concept b on a.condition_concept_id = b.concept_id
       limit 10"
)
# Out:
#    condition_occurrence_id condition_concept_id condition_source_value
# 1   7.000818e+18             196523             78791
# 2  -3.514320e+18             436659             2809
# 3  -6.297447e+18             435515             2761
# 4   3.131133e+18             436096             33829
# 5   2.246710e+18             440383             311
# 6   3.281005e+18           37311319             27652
# 7  -3.356551e+18             373764             34982
# 8   2.389445e+18             443238             25002
# 9  -2.365441e+18             197672             78830
# 10  8.104095e+18             194406             59969
#    concept_name
# 1  NA
# 2  NA
# 3  NA
# 4  NA
# 5  NA
# 6  NA
# 7  NA
# 8  NA
# 9  NA
# 10 NA
