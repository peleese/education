# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 6.2 MB/s  0:00:02m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 13.2 MB/s  0:00:01m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]2m2/3 [pandas]
# ...

# %%
import pandas as pd
import zipfile
import os

# %%
## access zip of synthea OMOP data 
## load individual csv's of OMOP tables


zip_path = "synthea_sample_data_csv_latest.zip"  # adjust to your ZIP filename
extract_dir = "data"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# %%
print("Extracted files:", os.listdir(extract_dir))
# Out:
# Extracted files: ['organizations.csv', 'supplies.csv', 'careplans.csv', 'conditions.csv', 'procedures.csv', 'providers.csv', 'patients.csv', 'claims_transactions.csv', 'devices.csv', 'allergies.csv', 'claims.csv', 'imaging_studies.csv', 'medications.csv', 'payers.csv', 'encounters.csv', 'observations.csv', 'payer_transitions.csv', 'immunizations.csv']

# %%
person = pd.read_csv("data/patients.csv")

condition_occurrence =pd.read_csv("data/conditions.csv")

visit_occurrence = pd.read_csv("data/encounters.csv")

drug_exposure = pd.read_csv("data/medications.csv")

observations = pd.read_csv("data/observations.csv")

proceure_occurrence = pd.read_csv("data/procedures.csv")

# %%
dataframe_vars = [var_name for var_name, var_val in globals().items() if isinstance(var_val, pd.DataFrame)]

print("DataFrames currently in memory:", dataframe_vars)
# Out:
# DataFrames currently in memory: ['_', 'df_person', '_10', 'person', 'condition_occurrence', 'visit_occurrence', 'drug_exposure', 'observations', 'proceure_occurrence']
